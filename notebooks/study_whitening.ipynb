# %%
import numpy as np
import seaborn as sns
from pyneurode.spike_sorter import *
# Out:
# C:\Users\teristam\Anaconda3\envs\oeEnv\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
plugin_folder = 'D:\\Documents\\GitHub\\OE_whitening\\OE_whitening\\Build'

with open(plugin_folder+'\\whitening_results.txt','r') as f:
    lines = f.readlines()

# %%
covMatrix = np.loadtxt(lines[18:34])
W_wh = np.loadtxt(lines[52:68])

# %%
sns.heatmap(W_wh)

# %%
sns.heatmap(covMatrix)

# %%
with open(plugin_folder+'\\buffer.csv','r') as f:
    buffer = np.loadtxt(f.readlines())

# %%
buffer.shape
# Out:
# (16, 60000)

# %%
plt.figure(figsize=(15,18))
plot_multichannel(buffer)

# %%
data = buffer - np.mean(buffer, axis=1, keepdims=True)
AAt = data @ np.transpose(data)
AAt = AAt / data.shape[1]
sns.heatmap(AAt)
